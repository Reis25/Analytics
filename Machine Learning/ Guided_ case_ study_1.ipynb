# %% [markdown]
# <a href="https://colab.research.google.com/github/Reis25/AprendizadoDeMquinas/blob/master/avaliaca1_am_demetriosreis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIVERSIDADE FEDERAL DE ALAGOAS
#
# INSTITUTO DE COMPUTAÇÃO
#
# Aluno(a):
#
# Profs: Evandro Costa e Xu Yang
#
# Curso: Aprendizado de Máquina
#
# Prova 01
#
# INSTRUÇÕES: Entregue até 07/09/2020, 9:00.

# %% [markdown]
# (1) Dado os dados de iris.csv, calcule a matriz de covariança e faça um scatter
# plot. Baseado na matriz e scatter plot, discuta a independência dos atributos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# URL dataset iris.csv
url1 = 'https://raw.githubusercontent.com/Reis25/Testes_py/5644d84ac36d824c9294506a387dc8872913e280/iris.csv'

# Data Frame Balance.csv
data_frame1 = pd.read_csv(url1)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Visualizando uma porção dos dados de iris.csv
data_frame1.head()
# Out:
#      lsepal    wsepal    lpetal    wpetal        class
# 0  0.222222  0.625000  0.067797  0.041667  Iris-setosa
# 1  0.166667  0.416667  0.067797  0.041667  Iris-setosa
# 2  0.111111  0.500000  0.050847  0.041667  Iris-setosa
# 3  0.083333  0.458333  0.084746  0.041667  Iris-setosa
# 4  0.194444  0.666667  0.067797  0.041667  Iris-setosa

# %%
# Informações da base de dados
data_frame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lsepal  150 non-null    float64
#  1   wsepal  150 non-null    float64
#  2   lpetal  150 non-null    float64
#  3   wpetal  150 non-null    float64
#  4   class   150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Calculando a matriz de covariancia para o dataset irirs.csv
data_frame1.cov()
# Out:
#           lsepal    wsepal    lpetal    wpetal
# lsepal  0.052908 -0.004545  0.059966  0.059827
# wsepal -0.004545  0.032640 -0.022720 -0.020483
# lpetal  0.059966 -0.022720  0.089433  0.091553
# wpetal  0.059827 -0.020483  0.091553  0.101114

# %%
# Scatter plot do dataset iris.csv
iris = sns.load_dataset("iris")
iris = iris.rename(index = str, columns = {'sepal_length':'1_sepal_length','sepal_width':'2_sepal_width', 'petal_length':'3_petal_length', 'petal_width':'4_petal_width'})

sns.FacetGrid(iris, hue="species", size=7) .map(plt.scatter,"1_sepal_length", "2_sepal_width", )  .add_legend()
plt.title('Scatter plot')
df1 = iris[["1_sepal_length", "2_sepal_width",'species']]
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Podemos analisar em nossa análise alguns gráficos como por exemplo:
#
# I) A correlação básica com regressão;
#
# II) A correlação dos dados de forma separada bem como sua distribuição;
#
# III) O mapa de calor.
#
#  Assim temos:

# %%
# Correlação Básica com regressão referente ao dataset iris.csv 
sns.pairplot(data_frame1, kind="reg")
plt.show()

# %%
# Correlção com dados separados bem como suas distribuições
sns.pairplot(data_frame1, kind="reg", hue="class", markers=["o", "s", "D"], palette="Set2")
plt.show()

# %%
# Mapa de calor em relativa à correlçao entre as variáveis. 
plt.figure(figsize=(7,7))

sns.heatmap(data_frame1.corr(), annot=True)

# %% [markdown]
# Interpretação: Temos um dataset com 5 colunas e 150 linhas, onde buscamos classificar um objeto que possui 4 características e pode ser classificado em três classes.
#
# A matriz de covariância busca estabeler uma relação entre as variáveis ou mesmo a ausência de relação entre elas, é importante destacar que que se o elemento da matriz é positivo, então as duas variáveis crescem e decrescem juntas, ou seja, são correlacioadas enquanto que que se o elemento for negativo mostra que enquanto uma variável cresce a decresce. Assim contextualizando note que existe uma correlçaão positiva ente lsepal e lpetal e que por sua vez é muito similar a covariância entre lsepal e wpetal, em seguida deve-se destacar a "força" de crescimento positivo entre wpetal e lpetal.
# Contrastando os dados acima vemos uma correlção negativa entre: wpetal e lsepal, lpetal e wsepal e wpetal e wpetal, destacando que essa penultima covariancia é a mais forte como mostram os dados.
#
# Analisando nosso gráfico de dispersão ( ou scatter plot), é um gráfico que busca verificar se entre variáveis (geralmente duas) possuem uma relação de causa e efeito, note que se usássemos apenas o gráfico de dispersão teríamos apenas os dados totalmente clasterizados mostrando que há grupos diferentes em nossa base de dados, no entanto olhando o gráfico da Correlação Básica com regressão referente ao dataset iris.csv vemos que podemos uma força notável entre as variáveis que possuiam covariancia positiva.
#
# *Lembrando que correlção nos mostra como os dados relacionam-se entre si, uma vez que a ideia de correlação indica a independência entre duas ou mais variáveis.

# %% [markdown]
# (2) Considere uma SVM cujos hiperplanos canônicos sejão H1 : w x X + b = 1 e
# H2 : w x X + b = -1. Demonstre que a maximização da margem de separação dos
# objetos em relação a w  x X + b = 0 pode ser obtida pela minimização de ||w||.

# %% [markdown]
# ![GitHub Logo](https://raw.githubusercontent.com/Reis25/Testes_py/master/img1.jpg)
#
# ![GitHub Logo](https://raw.githubusercontent.com/Reis25/Testes_py/master/img2.jpg)

# %% [markdown]
# (3) Dado os dados de Iris.csv:

# %% [markdown]
# (a) Calcule a probabilidade a priori para cada classe.

# %%
print(data_frame1['class'].value_counts())
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: class, dtype: int64

# %% [markdown]
# Dado que temos 150 itens e e cada classe possui exatamente 50 dados. Cada uma das classes tem aproximadamente 33,33% de chance de acontecer.

# %% [markdown]
# (b) Para um objeto x = (4.8, 3.1, 1.5, 0.2), calcular a verossimilhança.

# %%
Y_pp = pd.DataFrame(gaussian.predict_proba(x_analise), 
             columns=['class_virginica', 'class_setosa', 'class_Versicolor'])
Y_pp.head()
# Out:
#    class_virginica  class_setosa  class_Versicolor
# 0              0.0  4.387828e-12               1.0

# %% [markdown]
# (c) Pelo Naive Bayes, qual classe o novo dado deve estar?

# %%
# Algoritmo de Naive Bayes

# importação das bibliotecas: 
import numpy as np 
import pandas as pd 
from sklearn.model_selection import KFold,train_test_split,cross_val_score
from sklearn.naive_bayes import GaussianNB

#Metrics
from sklearn.metrics import make_scorer, accuracy_score,precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score

# %%
data_frame1.head()
# Out:
#      lsepal    wsepal    lpetal    wpetal        class
# 0  0.222222  0.625000  0.067797  0.041667  Iris-setosa
# 1  0.166667  0.416667  0.067797  0.041667  Iris-setosa
# 2  0.111111  0.500000  0.050847  0.041667  Iris-setosa
# 3  0.083333  0.458333  0.084746  0.041667  Iris-setosa
# 4  0.194444  0.666667  0.067797  0.041667  Iris-setosa

# %%
data_frame1["id"] = data_frame1.insert(0,"ID", range(1, 1+len(data_frame1)))

# %%
data_frame1 = data_frame1.drop(columns=['id'])

# %%
data_frame1.head()
# Out:
#    ID    lsepal    wsepal    lpetal    wpetal        class
# 0   1  0.222222  0.625000  0.067797  0.041667  Iris-setosa
# 1   2  0.166667  0.416667  0.067797  0.041667  Iris-setosa
# 2   3  0.111111  0.500000  0.050847  0.041667  Iris-setosa
# 3   4  0.083333  0.458333  0.084746  0.041667  Iris-setosa
# 4   5  0.194444  0.666667  0.067797  0.041667  Iris-setosa

# %%
# Criando o conjunto de dados a partir do dataset
X = data_frame1.drop(['lsepal', 'class'], axis=1)
y = data_frame1['class']

# Separação do conjunto de dados 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# Métrica Gaussiana 
gaussian = GaussianNB()

# Fit ajustável com a curva Gaussiana 
gaussian.fit(X_train, y_train)
Y_pred = gaussian.predict(X_test) 
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)

# Construindo a matriz de confusão 
cm = confusion_matrix(y_test, Y_pred)

# acc
accuracy = accuracy_score(y_test,Y_pred)

precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')

# Mostrando o resultado das Métricas: 
print('Matriz de confusão para o Naive Bayes\n',cm,"\n")
print('accuracia para Naive Bayes: %.3f' %accuracy, '\n')
print('precision para Naive Bayes: %.3f' %precision, '\n')
print('recall para o Naive Bayes: %.3f' %recall, '\n')
print('f1-score para o Naive Bayes : %.3f' %f1, "\n\n")

# Dados a ser analisado: 
x_analise = [ [4.8, 3.1, 1.5, 0.2]]

# Predição da questão 
print('Predição para o ponto (',x_analise,')=', gaussian.predict(x_analise))
# Out:
# Matriz de confusão para o Naive Bayes
#  [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
#
# accuracia para Naive Bayes: 1.000
#
# precision para Naive Bayes: 1.000
#
# recall para o Naive Bayes: 1.000
#
# f1-score para o Naive Bayes : 1.000
#
#
# Predição para o ponto ( [[4.8, 3.1, 1.5, 0.2]] )= ['Iris-virginica']

# %%
# Informações do dataset

print(X.head())
print(X.shape)
print("-----------------------------------------\n")

print(y.head())
print(y.shape)
print("-----------------------------------------\n")

# Conjunto de treino 
print(X_train.shape)
print(y_train.shape)
print("-----------------------------------------\n")

# Conjunto de teste
print(X_test.shape)
print(y_test.shape)
print("-----------------------------------------\n")
# Out:
#    ID    wsepal    lpetal    wpetal
# 0   1  0.625000  0.067797  0.041667
# 1   2  0.416667  0.067797  0.041667
# 2   3  0.500000  0.050847  0.041667
# 3   4  0.458333  0.084746  0.041667
# 4   5  0.666667  0.067797  0.041667
# (150, 4)
# -----------------------------------------
#
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: class, dtype: object
# (150,)
# -----------------------------------------
#
# (120, 4)
# (120,)
# -----------------------------------------
#
# (30, 4)
# (30,)
# -----------------------------------------

# %% [markdown]
# (4) Para os dados de Balança, considere as questões seguintes:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns; sns.set()

# URL para o dataset balace_scale_dataset.csv 
url2 = 'https://raw.githubusercontent.com/Reis25/Testes_py/5644d84ac36d824c9294506a387dc8872913e280/balance_scale_dataset%20-%20balance_scale_dataset.csv'

# Data Frame Balance.csv
data_frame2 = pd.read_csv(url2)

# %% [markdown]
# (a) Sugira uma rede neural para classificar (para 3 grupos) e explica as arquitetura e aprendizado (números de entradas, saídas, algoritmos de treinamento, etc ).

# %%
print(data_frame2['balance'].value_counts())
# Out:
# L    288
# R    288
# B     49
# Name: balance, dtype: int64

# %%
data_frame2.head()
# Out:
#    left_weight  left_distance  right_weight  right_distance balance
# 0            1              1             1               1       B
# 1            1              1             1               2       R
# 2            1              1             1               3       R
# 3            1              1             1               4       R
# 4            1              1             1               5       R

# %%
# Multlayer perceptron 

# Carregando as bibliotecas: 
import numpy as np 
import pandas as pd 
import seaborn as sns 

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# Fazendo a separação nosso conjunto de treino e teste, usando: from sklearn.model_selection import train_test_split
X = data_frame2[['left_weight',	'left_distance',	'right_weight',	'right_distance']]
y = data_frame2['balance']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)


from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data_frame2["balance"] = labelencoder.fit_transform(data_frame2["balance"])
balance = pd.DataFrame({'balance': ['R', 'B', 'L']})


def create_dummies(df,column_name):
    dummies = pd.get_dummies(df[column_name],prefix=column_name)
    df = pd.concat([df,dummies],axis=1)
    return df
data = create_dummies(data_frame2,"balance")

# Features achadas antes da normalização: 
unscaled_features = X_train

# normalizando para que possamos otimizar o classificador, fazendo: 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# Aqui calculamos a média e o desvio padrão e aplica na transformação 
X_train_array = sc.fit_transform(X_train.values)

# Assign the scaled data to a DataFrame & use the index and columns arguments to keep your original indices and column names:
X_train = pd.DataFrame(X_train_array, index=X_train.index, columns=X_train.columns)

# Dados de teste do centro com o μ & σ computando (fitted) sobre o conjunto de teste
X_test_array = sc.transform(X_test.values)
X_test = pd.DataFrame(X_test_array, index=X_test.index, columns=X_test.columns)


# Antes e depois do processo de normalização, note que não a necessidade, no entanto mantivemos como forma de mostrar o algoritmo na íntegra 
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(6, 5))

# Antes da normalização
ax1.set_title('Before Scaling')
sns.kdeplot(unscaled_features['left_weight'], ax=ax1)
sns.kdeplot(unscaled_features['left_distance'], ax=ax1)
sns.kdeplot(unscaled_features['right_weight'], ax=ax1)
sns.kdeplot(unscaled_features['right_distance'], ax=ax1)

# Depois da normalização
ax2.set_title('After Scaling')
sns.kdeplot(X_train['left_weight'], ax=ax2)
sns.kdeplot(X_train['left_distance'], ax=ax2)
sns.kdeplot(X_train['right_weight'], ax=ax2)
sns.kdeplot(X_train['right_distance'], ax=ax2)

plt.show()

# %%
#Importando o modelo que vamos gerar o modelo 
from sklearn.neural_network import MLPClassifier

# Iniciiaizando o multilayer perceptron
mlp = MLPClassifier(solver='sgd', alpha=1e-5,
                     hidden_layer_sizes=(10,), learning_rate_init= 0.01, max_iter=500)

print(mlp.fit(X_train, y_train))
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(10,), learning_rate='constant',
#               learning_rate_init=0.01, max_fun=15000, max_iter=500,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='sgd',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
# Predição para o X_test e comparando com y_test
print(mlp.score(X_test,y_test))
# Out:
# 0.968

# %%
# Eliminando as linhas da classe 'B'
data_frame2 = data_frame2.drop(data_frame2[data_frame2.balance == 'B'].index)

# %%
# Verificando a remoção das linhas: 
print(data_frame2['balance'].value_counts())
# Out:
# L    288
# R    288
# Name: balance, dtype: int64

# %% [markdown]
# (b) Não considera a classe equilibrada (ignora os objetos de classe equilibrada), usa SVM para classificar os dados.

# %%
# Algoritmo de SVM-linear (suporte Vector Machine)

# importação das bibliotecas: 
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC

# Nomeando os conjuntos a serem analisados 
y = np.array(data_frame2[['balance']])
x = np.array(data_frame2.drop(['left_weight', 'balance'], axis=1))

# Separação do conjunto de treino e conjunto de test
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33, stratify=y)

#Fit do plot
model = LinearSVC()
model.fit(x_train, y_train.ravel())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
#Calculate Test Prediction
y_pred = model.predict(x_test)
print("acuracia da precisão do modelo: ",model.score(x_test,y_test.ravel()), "\n\n")

print("Conjunto de classe (conjunto y): \n")
print(y[0:5])

print("------------------------------------- \n")

print("Conjunto de valores (conjunto x): \n")
print(x[0:5])

print("------------------------------------- \n")

print("Mapa de calor: ")
# Plotagem de matriz de correlção
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

import matplotlib.pyplot as plt
import seaborn as sn

df_cm = pd.DataFrame(cm, index = [i for i in np.unique(y)],
                  columns = [i for i in np.unique(y)])
plt.figure(figsize = (5,5))
sn.heatmap(df_cm, annot=True)
# Out:
# acuracia da precisão do modelo:  0.8219895287958116
#
#
# Conjunto de classe (conjunto y):
#
# [['R']
#  ['R']
#  ['R']
#  ['R']
#  ['R']]
# -------------------------------------
#
# Conjunto de valores (conjunto x):
#
# [[1 1 2]
#  [1 1 3]
#  [1 1 4]
#  [1 1 5]
#  [1 2 1]]
# -------------------------------------
#
# Mapa de calor:

# %% [markdown]
# (c) Não considera a classe equilibrada (ignora os objetos de classe equilibrada), usa Naive Bayes para classificar os dados. Compara os resultados com a SVM.

# %%
# Algoritmo de Naive Bayes

# importação das bibliotecas: 
import numpy as np 
import pandas as pd 
from sklearn.model_selection import KFold,train_test_split,cross_val_score
from sklearn.naive_bayes import GaussianNB

#Metrics
from sklearn.metrics import make_scorer, accuracy_score,precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score


y = np.array(data_frame2[['balance']])

# Juntando  
X = np.array(data_frame2.drop(['left_weight', 'balance'], axis=1))

# Separação do conjunto de dados 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# Métrica Gaussiana 
gaussian = GaussianNB()

# Fit ajustável com a curva Gaussiana 
gaussian.fit(X_train, y_train)
Y_pred = gaussian.predict(X_test) 
accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)

# Construindo a matriz de confusão 
cm = confusion_matrix(y_test, Y_pred)
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')

print('Matriz de confusão para o Naive Bayes\n',cm,"\n")
print('accuracia para Naive Bayes: %.3f' %accuracy, '\n')
print('precision para Naive Bayes: %.3f' %precision, '\n')
print('recall para o Naive Bayes: %.3f' %recall, '\n')
print('f1-score para o Naive Bayes : %.3f' %f1, "\n\n")
# Out:
# Matriz de confusão para o Naive Bayes
#  [[71 18]
#  [ 9 75]]
#
# accuracia para Naive Bayes: 0.844
#
# precision para Naive Bayes: 0.844
#
# recall para o Naive Bayes: 0.844
#
# f1-score para o Naive Bayes : 0.844
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:206: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# Conclusão: o algoritmo de Naive bayes mostrar ser mais preciso com uma acurácia levemente maior que o SVM de classificação linear.

# %% [markdown]
# (5) (1’)Considere o conjunto de treinamento, hipotético, abaixo, referente à “condição de obesidade”, apresentado a seguir, contendo um conjunto de 8 exemplos, com 4 atributos e um atributo classificador. Considere ainda os algoritmos para geração de árvores de decisão ID3 e C4.5, e o algoritmo PRISM para construção de regras de classificação, tais como vistos na disciplina AM. Use tais algoritmos para construir, manualmente, as respectivas árvores de decisão completas (em seguida mostrando as regras derivadas das árvores ID3 e C4.5) e as regras produzidas pela execução do PRISM. Mostre o passo a passo do processo de construção das árvores (via ID3 e C4.5) e das regras de classificação (via PRISM), apresentando os cálculos envolvidos, critério e justificativa de escolha para cada atributo candidato a ser raiz de árvore (e cada subárvore), em cada momento. Após a árvore ser construída, extraia e apresente as regras correspondentes às árvores de decisão construídas (com ID3 e C4.5). Ao final, faça uma discussão comparativa, considerando critérios técnicos de sua livre escolha, entre os resultados obtidos pelos 3 classificadores.
#
# Exemplo | Come | Vegetariano | Idade | Diabético | Classe
# :--------- | :------: | -------:  | -------:  | -------:  | -------:
# 1 | pouco | sim | velho | sim | magro
# 2 | médio | sim | velho | não |  magro
# 3 | muito | não | velho | sim | gordo
# 4 | pouco | não | velho | não | magro
# 5 | médio | não | jovem | sim | gordo
# 6 | pouco | sim | jovem | não | magro
# 7 | muito | não | velho | não | gordo
# 8 | médio | não | jovem | sim | gordo
#
#
# Escolha uma biblioteca/pacote de AM de sua preferência (Scikit Learn, Weka,
# R, . . . ) e rode os 3 algoritmos (entregando as soluções obtidas na implementação),
# verificando se os resultados das regras coincidem com os produzidos manualmente.

# %%
# ID3

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import graphviz

# URL para o dataset obesidade.csv
url3 = 'https://raw.githubusercontent.com/Reis25/Testes_py/master/obesidade.csv'

# Data frame obesidade.csv
data_frame3 = pd.read_csv(url3)

# %%
# Leitura do dataset
data_frame3.head(10)
# Out:
#    Exemplo   Come Vegetariano  Idade Diabético Classe
# 0        1  pouco         sim  velho       sim  magro
# 1        2  médio         sim  velho       não  magro
# 2        3  muito         não  velho       sim  gordo
# 3        4  pouco         não  velho       não  magro
# 4        5  médio         não  jovem       sim  gordo
# 5        6  pouco         sim  jovem       não  magro
# 6        7  muito         não  velho       não  gordo
# 7        8  médio         não  jovem       sim  gordo

# %%
# Tratamento de dados: 

# Exluindo a coluna 'Exemplo'
data_frame3 = data_frame3.drop(['Exemplo'], axis=1)

# substituindo valores categóricos por valores numéricos: 
df_getdummy = pd.get_dummies(data=data_frame3, columns=['Come','Vegetariano', 'Idade','Diabético'])

# %%
# dataset numerico relativo ao diabetes.csv 
df_getdummy.head()
# Out:
#   Classe  Come_muito  Come_médio  ...  Idade_velho  Diabético_não  Diabético_sim
# 0  magro           0           0  ...            1              0              1
# 1  magro           0           1  ...            1              1              0
# 2  gordo           1           0  ...            1              0              1
# 3  magro           0           0  ...            1              1              0
# 4  gordo           0           1  ...            0              0              1
#
# [5 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

X = df_getdummy.drop('Classe',axis=1)
y = df_getdummy['Classe']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# criterion = entropy implica o algoritmo ID3
dtree = DecisionTreeClassifier(criterion="entropy", max_depth=3)
dtree.fit(X_train,y_train)
predictions = dtree.predict(X_test)

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# plot da árvore de decisão 
fig = plt.figure(figsize=(16,12))
a = plot_tree(dtree, feature_names=df_getdummy.columns, fontsize=12, filled=True, 
              class_names=['Magro', 'Gordo'])

# %%
# Mapa de correlação 

correlation = df_getdummy.corr()

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlation, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)

ax.set_xticks(ticks)
ax.set_yticks(ticks)

plt.show()

# %%
# C4.5

clf2 = sklearn.tree.DecisionTreeClassifier()

clf2.fit(X_train, y_train)

dot_data = tree.export_graphviz(clf2, out_file=None)

# plot da árvore de decisão 
fig = plt.figure(figsize=(16,12))
a = plot_tree(dtree, feature_names=df_getdummy.columns, fontsize=12, filled=True, 
              class_names=['Magro', 'Gordo'])

# %% [markdown]
# Interpretação e comparação:
# Quais são os vários algoritmos da árvore de decisão e como eles diferem uns dos outros00
#
# ID3 (Iterative Dichotomiser 3) foi desenvolvido em 1986 por Ross Quinlan. O algoritmo cria uma árvore de múltiplas vias, encontrando para cada nó (ou seja, de maneira gananciosa) a característica categórica que produzirá o maior ganho de informação para alvos categóricos. As árvores crescem até seu tamanho máximo e, em seguida, uma etapa de poda é geralmente aplicada para melhorar a capacidade da árvore de generalizar para dados invisíveis.
#
# C4.5 é o sucessor de ID3 e removeu a restrição de que os recursos devem ser categóricos, definindo dinamicamente um atributo discreto (com base em variáveis ​​numéricas) que particiona o valor do atributo contínuo em um conjunto discreto de intervalos. C4.5 converte as árvores treinadas (ou seja, a saída do algoritmo ID3) em conjuntos de regras se-então. A precisão de cada regra é avaliada para determinar a ordem em que devem ser aplicadas. A poda é feita removendo a pré-condição de uma regra se a precisão da regra melhorar sem ela.

# %% [markdown]
# (6) Mostre, com a ajuda de um conjunto de dados, 3 limitações (por exemplo:
# Lidar com algum tipo de overfitting, . . . ) presentes no algoritmo ID3, explicando-as e demonstrando como tais limitações podem ser resolvidas com o algoritmo C4.5.
#
# No mais, comprove suas respostas, demonstrando-as na prática com a execução do
# conjunto de treinamento em uma biblioteca/pacote de AM de sua preferência (Scikit
# Learn, Weka, R, . . . ), entregando a solução implementada.

# %%
url4 = 'https://raw.githubusercontent.com/Reis25/Testes_py/master/diabetes.csv'

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import graphviz

df = pd.read_csv(url4)
df = df.drop('SkinThickness', 'columns')
df = df.dropna()

df = df[(df[['Glucose','BloodPressure','Insulin', 'BMI','DiabetesPedigreeFunction','Age']] != 0).all(axis=1)]

split_data = train_test_split(df, test_size=.30)

train_data = split_data[0]
test_data = split_data[1]

outcome_train = train_data.Outcome.tolist()
outcome_test = test_data.Outcome.tolist()

train_data_remove = train_data.drop(columns = "Outcome")
test_data_remove = test_data.drop(columns = "Outcome")

# ID3
clf = sklearn.tree.DecisionTreeClassifier(criterion = "entropy")
clf.fit(train_data_remove, outcome_train)

dot_data = tree.export_graphviz(clf, out_file=None)
graph = graphviz.Source(dot_data)
graph.render("Diabetes")

graph

# %%
test_array = clf.predict(test_data_remove).tolist()
ID3TestAccuracy = sklearn.metrics.accuracy_score(outcome_test, test_array)

print('ID3 Testing accuracy: ',ID3TestAccuracy)
# Out:
# ID3 Testing accuracy:  0.8220338983050848

# %%
train_array2 = clf2.predict(train_data_remove).tolist()

CTrainAccuracy = sklearn.metrics.accuracy_score(outcome_train, train_array2)

print('C4.5 Training accuracy: ', CTrainAccuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-f28ba8b6909a> in <module>()
# ----> 1 train_array2 = clf2.predict(train_data_remove).tolist()
#       2
#       3 CTrainAccuracy = sklearn.metrics.accuracy_score(outcome_train, train_array2)
#       4
#       5 print('C4.5 Training accuracy: ', CTrainAccuracy)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     417         """
#     418         check_is_fitted(self)
# --> 419         X = self._validate_X_predict(X, check_input)
#     420         proba = self.tree_.predict(X)
#     421         n_samples = X.shape[0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     389                              "match the input. Model n_features is %s and "
# ...

# %%
correlation = df.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlation, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
plt.show()

# %%
train_array = clf.predict(train_data_remove).tolist()
ID3TrainAccuracy = sklearn.metrics.accuracy_score(outcome_train, train_array)

print('ID3 acuracia conjunto de treino: ',ID3TrainAccuracy)
# Out:
# ID3 acuracia conjunto de treino:  1.0

# %%
# C4.5
clf2 = sklearn.tree.DecisionTreeClassifier()

clf2.fit(train_data_remove, outcome_train)

dot_data = tree.export_graphviz(clf2, out_file=None)
graph = graphviz.Source(dot_data)
graph.render("Diabetes")

graph

# %%
test_array2 = clf2.predict(test_data_remove).tolist()
CTestAccuracy = sklearn.metrics.accuracy_score(outcome_test, test_array2)

print('C4.5 acuracia de teste: ',CTestAccuracy)
# Out:
# C4.5 Testing accuracy:  0.7288135593220338

# %%
train_array2 = clf2.predict(train_data_remove).tolist()

CTrainAccuracy = sklearn.metrics.accuracy_score(outcome_train, train_array2)

print('C4.5 Training accuracy: ', CTrainAccuracy)

# %%
prediction_test = clf.predict(test_data_remove).tolist()
print("Conjunto de test")
print('Matriz de confunsão no conjunto de teste usando ID3:')
print(confusion_matrix(outcome_test, prediction_test))
print()
print('Classificando o ID3')
print(classification_report(outcome_test, prediction_test))
print()
print()
print("TRAINING DATA")
prediction_train = clf.predict(train_data_remove).tolist()

print('Matriz de confunsão com conjunto de treino usando ID3:')
print(confusion_matrix(outcome_train, prediction_train))
print()
print('Classificando o ID3')
print(classification_report(outcome_train, prediction_train))
# Out:
# TESTING DATA
# Confusion Matrix with Testing Data with ID3 Algorithm:
# [[67 14]
#  [16 21]]
#
# Classification Report ID3 Algorithm:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82        81
#            1       0.60      0.57      0.58        37
#
#     accuracy                           0.75       118
#    macro avg       0.70      0.70      0.70       118
# weighted avg       0.74      0.75      0.74       118
#
#
#
# TRAINING DATA
# Confusion Matrix with Training Data with ID3 Algorithm:
# [[181   0]
#  [  0  93]]
#
# Classification Report ID3 Algorithm:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#            1       1.00      1.00      1.00        93
#
#     accuracy                           1.00       274
#    macro avg       1.00      1.00      1.00       274
# weighted avg       1.00      1.00      1.00       274

# %%
prediction_train2 = clf2.predict(train_data_remove).tolist()

print("Conjunto de teste")
print('Matriz de confunsão no conjunto de teste usando C4.5:')
print(confusion_matrix(outcome_train, prediction_train2))
print()
print('Classificando o C4.5:')
print(classification_report(outcome_train, prediction_train2))
print()
print()
print("conjunto de treinamento")
print('Confusion Matrix with Training Data with C4.5 Algorithm:')
print(confusion_matrix(outcome_train, prediction_train2))
print()
print('Classification Report C4.5 Algorithm:')
print(classification_report(outcome_train, prediction_train2))
# Out:
# TESTING DATA
# Confusion Matrix with Testing Data with C4.5 Algorithm:
# [[181   0]
#  [  0  93]]
#
# Classification Report C4.5 Algorithm:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#            1       1.00      1.00      1.00        93
#
#     accuracy                           1.00       274
#    macro avg       1.00      1.00      1.00       274
# weighted avg       1.00      1.00      1.00       274
#
#
#
# TRAINING DATA
# Confusion Matrix with Training Data with C4.5 Algorithm:
# [[181   0]
#  [  0  93]]
#
# Classification Report C4.5 Algorithm:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       181
#            1       1.00      1.00      1.00        93
#
#     accuracy                           1.00       274
#    macro avg       1.00      1.00      1.00       274
# weighted avg       1.00      1.00      1.00       274

# %% [markdown]
# Nota-se que o c4.5 tem um desempenho muito superior através das métricas expostas, sendo recomendado para grande conjuntos de dados e dados.

# %% [markdown]
# (7) Julgue, com argumentos técnicos e com demonstração experimental, as seguintes afirmações quanto às suas possíveis veracidades:
#
# (a) Os algoritmos de indução de árvores de decisão são robustos quanto à presença de ruído, num contexto de overfitting.
#
#
#
# *   De fato, algoritmos como o ID3 que possuem seu arcabouço fundamentado em métricas estatísticas pode não determinar leias que modelem o problema por sofrer com ruídos, nisso há uma precisão considerável quando as árvores são menores. O overfitting nada mais é do que o ajuste demasiado dos dados de treinamento, nisso na presença de ruídos ou quando o conjunto de treinamento não é representativo, este algoritmo pode produzir árvores em que há overfitting.
#
# A definição de overfitting (Gama (2004)), é: “uma árvore de decisão 'd' faz
# sobre-ajustamento aos dados se existir uma árvore 'd’ tal que: d tem menor erro
# que 'd’ no conjunto de treino mas 'd’ tem menor erro na população”.
#
# Para prevenir o problema do overfitting e
# melhorar a classificação deve-se realizar a poda da árvore.
#
#
# (b) A presença de atributos redundantes (atributo fortemente relacionado a outro) em um conjunto de dados para treinamento não afeta adversamente a precisão do modelo construído com indução de ADs.
#
#
#
# *   A afirmação acima não procede uma vez que o conjunto de teste já se torna uma dificuldade por não ser encontrado, nisso dados faltantes e ruidosos em geral pode dificultar encontrar a árvore que modele o problema.
#
#
#
# Na justificativa, utilize um conjunto de dados como exemplo.

# %% [markdown]
# (8) Escolher uma base de dados do repositório UCI e implemente uma solução de comitê bagging, com no mínimo de 3 classificadores. Neste sentido, realize as seguintes atividades:
#
# (i) Justifique a escolha da base de dados;

# %% [markdown]
# *   Dataset clássico que tem seus dados reiteradamente investigado.

# %% [markdown]
# (ii) Avalie o desempenho da versão single de cada classificador, para a base de dados escolhida, utilizando uma das métricas já apresentadas no curso;

# %% [markdown]
# (iii) Avalie o desempenho da versão bagging para cada classificador, para a base de dados escolhida, utilizando uma das métricas já apresentadas no curso;

# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pd.read_csv("https://raw.githubusercontent.com/Reis25/Testes_py/master/pima_data.csv",names=names)

# %%
data.head()
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
array = data.values
X = array[:,0:8]
Y = array[:,8]
cart = DecisionTreeClassifier()
num_tree = 10
seed = 2

model = BaggingClassifier(cart,n_estimators=num_tree,random_state=seed)
kfold = KFold(n_splits=10,random_state=seed)
result = cross_val_score(model,X,Y,cv=kfold)

print("resultado: :",result.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# resultado: : 0.7421907040328093

# %%
clf_t = sklearn.tree.DecisionTreeClassifier()

clf_t.fit(X, Y)

#resultadox = sklearn.metrics.accuracy_score(X,Y)

#print("resultado: :",resultadox.mean())
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# (iv) Faça análise crítica e comparativa entre a versão single e bagging dos classificadores utilizados.
#
# Obs.: Para implementação, utilize a linguagem de programação de sua preferência

# %% [markdown]
# Temos uma melhor reresetanção do modelo de Bagging uma vez que o memso Quando se trabalha com “Classificadores
# Fracos” (Redes Neurais, Árvores de Decisão,
# etc):
# Um bom desempenho no conjunto de treinamento não
# prediz um bom desempenho de generalização;
# * Um conjunto de classificadores com desempenhos
# similares no conjunto de classificação podem ter
# diferentes desempenhos de generalização;
# * Mesmo classificadores com desempenhos de
# generalização similares podem trabalhar
# diferentemente;
#
# Nisso A combinação das saídas produzidas pelos
# classificadores reduz o risco de escolha por um
# classificador com um baixo desempenho
# Não seguir apenas a “recomendação” de um único
# especialista, essa melhora occorre justamente para idéia é construir muitos classificadores e
# então combinar suas saídas de modo que o
# desempenho final seja melhor do que o
# desempenho de um único classificador;
